# %%
import os
import sys
import timeit
import time
import random
import argparse
import itertools
import pandas as pd
import numpy as np
from functools import partial

import multiprocessing 
from multiprocessing import Pool, Value, Lock, Manager

from rdkit import Chem
from rdkit.Chem import AllChem, rdChemReactions, rdmolfiles, rdmolops

from template_utils.amol_utils_rdchiral import Reaction, Binarizer, Parsers

# %%
datafile = # Path to .csv file containing data

# %%
p = Parsers()
print('Parsing: {}'.format(datafile))
reaction_data = p.import_USPTO(datafile)
dataset = pd.DataFrame(columns=["ID", "reaction_hash", "reactants", "products", "classification", "retro_template", "template_hash", "selectivity", "outcomes"])
failed = []
# Out:
# Parsing: uspto_test_data/raw_data/xzaaa

# %%
rxn_number=0
extracted=0
for index, row in reaction_data.iterrows():
    rxn_number+=1
    print('Reaction: {}'.format(rxn_number))
    reaction = Reaction(row["rsmi"], rid=row["ID"])
    try:
        if len(reaction.rsmi.split('>')) > 3:
            failed.append([row["ID"], row["rsmi"], "components > 3"])
            continue
        elif len(reaction.product_list) > 1:
            failed.append([row["ID"], row["rsmi"], "products > 1"])
            continue
        elif reaction.incomplete_reaction():
            failed.append([row["ID"], row["rsmi"], "incomplete"])
            continue
        elif reaction.equivalent_reactant_product_set():
            failed.append([row["ID"], row["rsmi"], "reactants = products"])
            continue
        elif reaction.generate_reaction_template(radius=1) is None:
            failed.append([row["ID"], row["rsmi"], "template generation failure"])
            continue
        elif reaction.validate_retro_template(reaction.retro_template) is None:
            failed.append([row["ID"], row["rsmi"], "template rdkit validation failed"])
            continue
        elif reaction.check_retro_template_outcome(reaction.retro_template, reaction.products, save_outcome=True) != 0:
            outcomes = len(reaction.retro_outcomes)
            assessment = reaction.assess_retro_template(reaction.retro_template, reaction.reactant_mol_list, reaction.retro_outcomes)
        else: 
            pass
    except:
        continue
  

    rinchi_hash = reaction.generate_concatenatedRInChI()
    row_list = [row["ID"],
                rinchi_hash,
                reaction.reactants,
                reaction.products,
                row["classification"],
                reaction.retro_template,
                reaction.hash_template(reaction.retro_template),
                assessment,
                outcomes]

    row = pd.DataFrame([row_list], columns=["ID", "reaction_hash", "reactants", "products", "classification", "retro_template", "template_hash", "selectivity", "outcomes"])
    dataset = dataset.append(row, sort = False)
    extracted += 1
    sys.stdout.flush()

print('Extracted: {}'.format(extracted))
failed_df = pd.DataFrame(failed, columns=["ID", "rsmi", "reason"])
output = dataset.drop_duplicates(subset="reaction_hash")
# Out:
# Reaction: 1
# Reaction: 2
# Reaction: 3
# Reaction: 4
# Reaction: 5
# Reaction: 6
# Reaction: 7
# Reaction: 8
# Reaction: 9
# Reaction: 10
# Reaction: 11
# Reaction: 12
# Reaction: 13
# Reaction: 14
# Reaction: 15
# Could not find consistent tetrahedral mapping, 1 centers
# Template could not be extracted
# Reaction: 16
# Reaction: 17
# Reaction: 18
# Reaction: 19
# Reaction: 20
# Reaction: 21
# Reaction: 22
# Reaction: 23
# Reaction: 24
# Reaction: 25
# Reaction: 26
# Reaction: 27
# Reaction: 28
# Reaction: 29
# Reaction: 30
# Reaction: 31
# Reaction: 32
# Reaction: 33
# Reaction: 34
# Reaction: 35
# Reaction: 36
# Reaction: 37
# Reaction: 38
# Reaction: 39
# Reaction: 40
# Reaction: 41
# Reaction: 42
# Reaction: 43
# Reaction: 44
# Reaction: 45
# Reaction: 46
# Reaction: 47
# Reaction: 48
# Reaction: 49
# Reaction: 50
# Reaction: 51
# Reaction: 52
# Reaction: 53
# Reaction: 54
# Reaction: 55
# Reaction: 56
# Reaction: 57
# Reaction: 58
# Could not find consistent tetrahedral mapping, 1 centers
# Template could not be extracted
# Reaction: 59
# Reaction: 60
# Could not find consistent tetrahedral mapping, 1 centers
# Template could not be extracted
# Reaction: 61
# Could not find consistent tetrahedral mapping, 1 centers
# Template could not be extracted
# Reaction: 62
# Reaction: 63
# Could not find consistent tetrahedral mapping, 1 centers
# Template could not be extracted
# Reaction: 64
# Reaction: 65
# Reaction: 66
# Could not find consistent tetrahedral mapping, 1 centers
# Template could not be extracted
# Reaction: 67
# Reaction: 68
# Reaction: 69
# Reaction: 70
# Could not find consistent tetrahedral mapping, 1 centers
# Template could not be extracted
# Reaction: 71
# Reaction: 72
# Reaction: 73
# Reaction: 74
# Reaction: 75
# Reaction: 76
# Reaction: 77
# Reaction: 78
# Reaction: 79
# Reaction: 80
# Reaction: 81
# Reaction: 82
# Reaction: 83
# Reaction: 84
# Reaction: 85
# Reaction: 86
# Reaction: 87
# Reaction: 88
# Reaction: 89
# Reaction: 90
# Reaction: 91
# Reaction: 92
# Reaction: 93
# Reaction: 94
# Reaction: 95
# Reaction: 96
# Reaction: 97
# Could not find consistent tetrahedral mapping, 2 centers
# Template could not be extracted
# Reaction: 98
# Could not find consistent tetrahedral mapping, 2 centers
# Template could not be extracted
# Reaction: 99
# Reaction: 100
# Could not find consistent tetrahedral mapping, 2 centers
# Template could not be extracted
# Reaction: 101
# Could not find consistent tetrahedral mapping, 3 centers
# Template could not be extracted
# Reaction: 102
# Reaction: 103
# No transformation - invalid template
# Reaction: 104
# No transformation - invalid template
# Reaction: 105
# Could not find consistent tetrahedral mapping, 3 centers
# Template could not be extracted
# Reaction: 106
# Reaction: 107
# Reaction: 108
# Reaction: 109
# Reaction: 110
# Reaction: 111
# Reaction: 112
# Reaction: 113
# Reaction: 114
# Reaction: 115
# Reaction: 116
# Reaction: 117
# Reaction: 118
# Reaction: 119
# Reaction: 120
# Reaction: 121
# Reaction: 122
# Could not find consistent tetrahedral mapping, 1 centers
# Template could not be extracted
# Reaction: 123
# Reaction: 124
# Reaction: 125
# Could not find consistent tetrahedral mapping, 1 centers
# Template could not be extracted
# Reaction: 126
# Could not find consistent tetrahedral mapping, 1 centers
# Template could not be extracted
# Reaction: 127
# Reaction: 128
# Could not find consistent tetrahedral mapping, 1 centers
# Template could not be extracted
# Reaction: 129
# Reaction: 130
# Reaction: 131
# Reaction: 132
# Could not find consistent tetrahedral mapping, 1 centers
# Template could not be extracted
# Reaction: 133
# Reaction: 134
# Could not find consistent tetrahedral mapping, 1 centers
# Template could not be extracted
# Reaction: 135
# Reaction: 136
# Reaction: 137
# Reaction: 138
# Reaction: 139
# Reaction: 140
# Reaction: 141
# Reaction: 142
# Reaction: 143
# Reaction: 144
# Reaction: 145
# Reaction: 146
# Reaction: 147
# Reaction: 148
# Reaction: 149
# Reaction: 150
# Reaction: 151
# Reaction: 152
# Reaction: 153
# Reaction: 154
# Reaction: 155
# Reaction: 156
# Reaction: 157
# Reaction: 158
# Reaction: 159
# Reaction: 160
# Reaction: 161
# Reaction: 162
# Reaction: 163
# Reaction: 164
# Reaction: 165
# Could not validate reaction successfully
# retro_template: ([CH3;D1;+0:17]-[C;H0;D4;+0:18](-[CH3;D1;+0:14])(-[CH3;D1;+0:10])-[c;H0;D3;+0:6]1:[#7;a:5]:[c:4]:[c;H0;D3;+0:3](-[C;H0;D3;+0:23](=[O;D1;H0:24])-[#7:21]2-[CH2;D2;+0:20]-[CH2;D2;+0:19]-[C:8](-[#8:9]-[c;H0;D3;+0:10]3:[#7;a:11]:[c:12]:[#7;a:13]:[c;H0;D3;+0:14]4:[#7;a:15]:[#7;a:16]:[cH;D2;+0:17]:[c;H0;D3;+0:18]:4:3)-[CH2;D2;+0:7]-[CH2;D2;+0:22]-2):[c:2]:[cH;D2;+0:1]:1)>>(C-N(-C)-C(-O-n1:n:n:[c;H0;D3;+0:1]2:[c:2]:[cH;D2;+0:3]:[c:4]:[#7;a:5]:[c;H0;D3;+0:6]:2:1)=[N+](-C)-C).(C1-N-C-[CH2;D2;+0:7]-[C:8](-[#8:9]-[c;H0;D3;+0:10]2:[#7;a:11]:[c:12]:[#7;a:13]:[c;H0;D3;+0:14]3:[#7;a:15]:[#7;a:16]:[cH;D2;+0:17]:[c;H0;D3;+0:18]:3:2)-[CH2;D2;+0:19]-1).([CH3;D1;+0:20]-[#7:21](-[CH3;D1;+0:22])-[CH;D2;+0:23]=[O;D1;H0:24])
# Could not validate template - Invalid
# Reaction: 166
# Reaction: 167
# Reaction: 168
# Reaction: 169
# Reaction: 170
# Reaction: 171
# Reaction: 172
# Reaction: 173
# Reaction: 174
# Reaction: 175
# Reaction: 176
# Reaction: 177
# Reaction: 178
# Reaction: 179
# Reaction: 180
# Reaction: 181
# Reaction: 182
# Reaction: 183
# Reaction: 184
# Reaction: 185
# Reaction: 186
# Reaction: 187
# Reaction: 188
# Reaction: 189

# %%
output
# Out:
#                           ID  \
# 0   US20150238500A1;829;2015
# 0   US20150238500A1;831;2015
# 0   US20150238500A1;833;2015
# 0   US20150238500A1;835;2015
# 0   US20150238500A1;836;2015
# 0   US20150238500A1;837;2015
# 0   US20150238500A1;839;2015
# 0   US20150238500A1;840;2015
# 0   US20150238500A1;841;2015
# 0   US20150238500A1;842;2015
# 0   US20150238500A1;843;2015
# 0   US20150238500A1;845;2015
# 0   US20150238500A1;848;2015
# 0   US20150238500A1;850;2015
# 0   US20150238500A1;852;2015
# 0   [Cl:1][c:2]1[c:3]([CH3:12])[c:4]([Cl:11])[c:5]...
# 0   [CH3:1][c:2]1[cH:3][cH:4][c:5]2[c:6]([n:7][c:8...
# 0   [CH3:1][c:2]1[cH:3][c:4]([CH3:11])[c:5]2[c:6](...
# 0   [Cl:1][c:2]1[cH:3][c:4]([CH3:11])[c:5]2[c:6]([...
# 0   [Cl:1][c:2]1[cH:3][c:4]([CH2:11][CH3:12])[c:5]...
# 0   [Cl:1][c:2]1[c:3]([CH3:11])[cH:4][c:5]2[c:6]([...
# 0   [c:1]1([N:18]2[CH2:17][CH2:16][N:15]([CH3:14])...
# 0   [Cl:1][c:2]1[cH:3][cH:4][c:5]2[c:6]([n:7][c:8]...
# 0   [NH2:1][c:2]1[c:3]([Cl:4])[cH:5][c:6]2[c:7]([c...
# 0   [CH3:1][c:2]1[cH:3][c:4]([CH3:11])[c:5]2[c:6](...
# 0   [CH3:1][N:14]1[CH2:13][CH2:12][N:11]([c:10]2[n...
# 0   [NH2:1][c:2]1[cH:3][cH:4][c:5]([O:6][C:7]([CH3...
# 0   [CH2:1]([CH2:2][n:3]1[c:4]([CH2:5][CH3:6])[n:7...
# 0   [CH2:1]([CH3:2])[c:3]1[n:4]([CH2:16][CH2:17][O...
# 0   [CH:1]1([n:4]2[cH:5][c:6]([C:17]([O:18][CH2:27...
# 0   [F:1][c:2]1[cH:3][c:4]([NH:5][C:14]([O:13][CH2...
# 0   [c:1]1([N:19]2[CH2:18][CH2:17][N:16]([C:14]([O...
# 0   [F:1][c:2]1[c:3]([C:4](=[O:5])[C:15](=[CH:14][...
# 0   [C:1]([O:2][C:3]([CH3:4])([CH3:5])[CH3:6])(=[O...
# 0   [I:1][c:2]1[cH:3][cH:4][c:5]([C:8]2([C:9]#[N:1...
# 0   [C:1]([CH3:2])([CH3:3])([CH3:4])[O:5][C:6](=[O...
# 0   [NH:1]1[CH2:2][CH2:3][C:4]([c:5]2[cH:6][cH:7][...
# 0   [I:1][c:2]1[cH:3][cH:4][c:5]([C:6]2([C:7]#[N:8...
#
#                             classification  \
# 0                    Acid to acid chloride
# 0                     N-acylation to amide
# 0                               Unassigned
# 0                               Unassigned
# 0                  Heteroaryl N-alkylation
# 0                         NH deprotections
# 0                     N-acylation to amide
# 0                         Alkene to alkane
# 0                               Unassigned
# 0                               Unassigned
# 0                 Nitro to amine reduction
# 0                          O-sulfonylation
# 0                               Unassigned
# 0                     N-acylation to amide
# 0                               Unassigned
# 0                     N-acylation to amide
# 0                               Unassigned
# 0                           O-substitution
# 0                     N-acylation to amide
# 0                 Amide to amine reduction
# 0                           O-substitution
# 0                   Oxidations at nitrogen
# 0                        ROH deprotections
# 0                           O-substitution
# 0                               Unassigned
# 0                 Amide to amine reduction
# 0                         Other reductions
# 0                        Alcohol to halide
# 0   Other functional group interconversion
# 0                          Nitrile to acid
# ..                                     ...
# 0                               Unassigned
# 0                               Unassigned
# 0                               Unassigned
# 0                               Unassigned
# 0                               Unassigned
# 0                               Unassigned
# 0                               Unassigned
# 0                               Unassigned
# 0                               Unassigned
# 0                               Unassigned
# 0                               Unassigned
# 0                               Unassigned
# 0                               Unassigned
# 0                               Unassigned
# 0                               Unassigned
# 0                 Nitro to amine reduction
# 0                               Unassigned
# 0                      Reductive amination
# 0                 Nitro to amine reduction
# 0                           S-substitution
# 0                               Unassigned
# 0                               Unassigned
# 0                               Unassigned
# 0                    N-arylation with Ar-X
# 0                               Unassigned
# 0                           NH protections
# 0                               Unassigned
# 0                  Cyano or imine to amine
# 0                         NH deprotections
# 0                      Reductive amination
#
#                                        retro_template  \
# 0   ([Cl;H0;D1;+0]-[C;H0;D3;+0:1](=[O;D1;H0:2])-[c...
# 0   ([C;D1;H3:4]-[#8:5]-[C:6](-[#8:7]-[C;D1;H3:8])...
# 0   ([c:6]1:[c:7]:[c:8]:[c:9]:[c:10]:[c;H0;D3;+0:5...
# 0   ([CH3;D1;+0:2]-[CH2;D2;+0:1]-[n;H0;D3;+0:5]1:[...
# 0   ([C:3]-[N;H0;D3;+0:4](-[c:5])-[CH2;D2;+0:1]-[C...
# 0   ([C:2]-[NH;D2;+0:1]-[c:3])>>(C-C(=O)-[N;H0;D3;...
# 0   ([C:4]-[N;H0;D3;+0:5](-[c:6])-[C;H0;D3;+0:1](-...
# 0   ([CH2;D2;+0:5]1-[CH2;D2;+0:4]-[NH;D2;+0:3]-[c:...
# 0   ([c:2]:[c;H0;D3;+0:1]1:[c:3]:[cH;D2;+0:4]:[cH;...
# 0   ([C:4]-[N;H0;D3;+0:5](-[C:6])-[CH;D2;+0:1]=[CH...
# 0   ([NH2;D1;+0:1]-[c:2])>>(O=[N+;H0;D3:1](-[O-])-...
# 0   ([C:5]-[O;H0;D2;+0:6]-[S;H0;D4;+0:1](=[O;D1;H0...
# 0   ([C;D1;H3:1]-[#8:2]-[C:3](=[O;D1;H0:4])-[c;H0;...
# 0   ([O;D1;H0:4]=[C:3]-[C;H0;D3;+0:1](=[O;D1;H0:2]...
# 0   ([#7;a:6]:[c;H0;D3;+0:7](:[c:8])-[C;H0;D3;+0:1...
# 0   ([O;D1;H0:4]=[C:3]-[C;H0;D3;+0:1](=[O;D1;H0:2]...
# 0   ([#8:1]-[C:2]-[C;H0;D3;+0:3](=[O;H0;D1;+0:4])-...
# 0   ([C;D1;H3:2]-[CH2;D2;+0:1]-[O;H0;D2;+0:5]-[C:4...
# 0   ([#7;a:5]:[c:4]:[c:3]-[C;H0;D3;+0:1](=[O;D1;H0...
# 0   ([#7;a:14]:[c:13]:[c:12]-[CH2;D2;+0:3]-[#7:4]-...
# 0   ([#7;a:2]:[c;H0;D3;+0:1](:[c:3])-[O;H0;D2;+0:5...
# 0   ([O-;H0;D1:1]-[n+;H0;D3:3](:[c:2]):[c:4])>>(Cl...
# 0   ([C:2]-[OH;D1;+0:1])>>(C-C(-C)(-C)-[Si](-C)(-C...
# 0    US20150238500A1;849;2015
# 1    US20150238506A1;372;2015
# 2    US20150238506A1;491;2015
# 3    US20150238506A1;769;2015
# 4    US20080318981A1;209;2008
# 5    US20080318981A1;222;2008
# 6    US20080318981A1;228;2008
# 7    US20080318981A1;237;2008
# 8    US20080318981A1;247;2008
# 9    US20080318981A1;279;2008
# 10    US20080318991A1;84;2008
# 11    US20080318991A1;89;2008
# 12    US20080318991A1;95;2008
# 13    US20080318991A1;97;2008
# 14   US20080318991A1;111;2008
# 15   US20080318996A1;156;2008
# 16   US20080318996A1;162;2008
# 17   US20080318996A1;163;2008
# 18   US20080318996A1;167;2008
# 19   US20080318996A1;210;2008
# 20   US20080318996A1;224;2008
# 21   US20100093761A1;868;2010
# 22   US20100093769A1;171;2010
# 23   US20100093769A1;175;2010
# 24   US20100093769A1;179;2010
# 25   US20110039840A1;931;2011
# 26   US20110039840A1;996;2011
# 27   US20110039845A1;168;2011
# 28   US20110039846A1;422;2011
# 29   US20110039846A1;424;2011
# ..                        ...
# 81   US20160022626A1;509;2016
# 82   US20160022626A1;512;2016
# 83   US20160022626A1;536;2016
# 84   US20160022626A1;576;2016
# 85   US20160022626A1;589;2016
# 86   US20160022626A1;594;2016
# 87   US20160022626A1;623;2016
# 88   US20160022626A1;625;2016
# 89   US20160022626A1;643;2016
# 90   US20160022626A1;648;2016
# 91   US20160024020A1;674;2016
# 92   US20060155100A1;151;2006
# 93   US20060154960A1;663;2006
# 94   US20060155120A1;179;2006
# 95    US20060155130A1;48;2006
# 96   US20120071509A1;142;2012
# 97   US20120071509A1;147;2012
# 98   US20120071510A1;189;2012
# 99   US20120071514A1;236;2012
# 100  US20080146572A1;157;2008
# 101  US20080146572A1;161;2008
# 102  US20080146573A1;281;2008
# 103  US20080146570A1;217;2008
# 104  US20080146539A1;885;2008
# 105  US20080146539A1;957;2008
# 106  US20080146539A1;978;2008
# 107  US20030013730A1;114;2003
# 108  US20030013737A1;141;2003
# 109  US20030013737A1;142;2003
# 110  US20030013737A1;171;2003
#
#                                                   rsmi  \
# 0    CC(=N)O[CH2:10]C.CCN(CC)[CH2:1][CH3:2].[NH2:3]...
# 1    [OH:1][n:2]1[n:3][n:4][c:5]2[c:6]1[cH:7][cH:8]...
# 2    CC(C)(C)OC(=O)[N:1]1[CH2:2][CH2:3][N:4]([c:5]2...
# 3    CC(C)(C)OC(=O)[N:1]1[CH2:2][c:3]2[cH:4][c:5]([...
# 4    Cl[C@H:1]([CH3:2])[c:3]1[n:4][cH:5][cH:6][cH:7...
# 5    [C:1]([CH3:2])(=[O:3])[c:4]1[cH:5][c:6]([C:7]#...
# 6    N[c:1]1[s:2][c:3]2[c:4]([n:5][c:6]([SH:17])[n:...
# 7    Cl[C@H:20]([CH3:21])[c:22]1[cH:23][c:24]([C:25...
# 8    N[c:1]1[s:2][c:3]2[c:4]([n:5][c:6]([SH:16])[n:...
# 9    N[c:1]1[s:2][c:3]2[c:4]([n:5][c:6]([SH:17])[n:...
# 93   O[c:1]1[cH:2][c:3]([CH:4]=[O:5])[cH:6][cH:7][c...
# 94   O=C(OCC1c2ccccc2-c2ccccc21)ON1C(=O)CCC1=O.[Cl:...
# 95   [CH3:1][N:2]1[CH2:3][CH2:4][C@:5]23[c:6]4[c:7]...
# 96   [CH2:1]1[CH2:2][C:3](=[O:4])[NH:5][C:6](=[O:7]...
# 97   [CH2:1]1[CH2:2][C:3](=[O:4])[NH:5][C:6](=[O:7]...
# 98   [CH3:1][NH:2][S:3](=[O:4])(=[O:5])[CH2:6][c:7]...
# 99   Br[c:1]1[cH:2][n:3][cH:4][cH:5][c:6]1[CH:7]=[O...
# 100  CC(C)(C)OC(=O)[N:1]1[CH2:2][CH2:3][N:4]([c:5]2...
# 101  CC(C)(C)OC(=O)[N:1]1[CH2:2][CH2:3][N:4]([c:5]2...
# 102  CC(=O)[O:4][C:1]([CH3:2])=[O:3].NC[C@@H](CCl)[...
# 103  Cl[c:1]1[n:2][c:3](-[c:4]2[cH:5][n:6][cH:7][cH...
# 104  [NH2:1][c:2]1[c:3]([CH3:12])[cH:4][c:5]([C:6](...
# 105  C1CCC([NH:13][CH:11]2[CH2:10]CCC[CH2:12]2)CC1....
# 106  C1CCC([NH2+]C2CCCCC2)CC1.[O-][C:13]([C@@H:12](...
# 107  [CH2:1]([CH:2]=[CH2:3])[Br:4].[NH2:5][c:6]1[cH...
# 108  CC(C)C[O:10][C:9](=O)[NH:8][c:5]1[cH:4][c:3]([...
# 109  Cl[S:1]([c:2]1[cH:3][c:4]([N+:5](=[O:6])[O-:7]...
# 110  C1C[CH2:27][C:28](=[O:29])[N:26]1[CH3:25].Cl[c...
#
#                                reason
# 0         template generation failure
# 1                reactants = products
# 2                        products > 1
# 3                        products > 1
# 4         template generation failure
# 5         template generation failure
# 6         template generation failure
# 7         template generation failure
# 8         template generation failure
# 9         template generation failure
# 10        template generation failure
# 11        template generation failure
# 12        template generation failure
# 13        template generation failure
# 14        template generation failure
# 15        template generation failure
# 16        template generation failure
# 17        template generation failure
# 18        template generation failure
# 19        template generation failure
# 20        template generation failure
# 21   template rdkit validation failed
# 22        template generation failure
# 23   template rdkit validation failed
# 24        template generation failure
# 25                       products > 1
# 26                       products > 1
# 27   template rdkit validation failed
# 28                       products > 1
# 29                       products > 1
# ..                                ...
# 81        template generation failure
# 82                       products > 1
# 83                       products > 1
# 84                       products > 1
# 85        template generation failure
# 86                       products > 1
# 87                       products > 1
# 88        template generation failure
# 89                       products > 1
# 90        template generation failure
# 91   template rdkit validation failed
# 92                       products > 1
# 93        template generation failure
# 94        template generation failure
# 95        template generation failure
# 96               reactants = products
# 97               reactants = products
# 98               reactants = products
# 99   template rdkit validation failed
# 100                      products > 1
# 101                      products > 1
# 102       template generation failure
# 103                      products > 1
# 104  template rdkit validation failed
# 105       template generation failure
# 106       template generation failure
# 107                      products > 1
# 108       template generation failure
# 109       template generation failure
# 110       template generation failure
#
# [111 rows x 3 columns]
